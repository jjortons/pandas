# %%
import pandas as pd

import os
print(os.getcwd())
# Out:
# C:\myprojects\pd_psql

# %%
#%run c:/myprojects/pd_psql/pd_conn_psql_method1.ipynb
# connect to a postgresql db at localhost
# %run pandas-postgres-using-sqlalchemy.ipynb
# Out:
# Enter password to local postgresql database:  ········

# %%
df= pd.read_sql("select * from sales.salesorderdetail limit 8", ae)
df.tail()
# Out:
#    salesorderid  salesorderdetailid carriertrackingnumber  orderqty  \
# 3         43659                   4          4911-403C-98         1
# 4         43659                   5          4911-403C-98         1
# 5         43659                   6          4911-403C-98         2
# 6         43659                   7          4911-403C-98         1
# 7         43659                   8          4911-403C-98         3
#
#    productid  specialofferid  unitprice  unitpricediscount  \
# 3        771               1   2,039.99               0.00
# 4        772               1   2,039.99               0.00
# 5        773               1   2,039.99               0.00
# 6        774               1   2,039.99               0.00
# 7        714               1      28.84               0.00
#
#                                 rowguid modifieddate
# 3  04c4de91-5815-45d6-8670-f462719fbce3   2011-05-31
# 4  5a74c7d2-e641-438e-a7ac-37bf23280301   2011-05-31
# ...

# %%
df = pd.read_csv("../data_ex/fortune1000.csv", index_col= ["Rank"])
df
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# ...

# %%
df[["Revenue", "Profits", "Employees"]].sum()
# Out:
# Revenue      13535525
# Profits        894093
# Employees    33028002
# dtype: int64

# %%
mask1= df["Sector"] == "Energy"
df[mask1].sort_values(by= "Revenue", ascending= False)
# Out:
#                         Company  Sector                      Industry  \
# Rank
# 2                   Exxon Mobil  Energy            Petroleum Refining
# 14                      Chevron  Energy            Petroleum Refining
# 30                  Phillips 66  Energy            Petroleum Refining
# 32                Valero Energy  Energy            Petroleum Refining
# 42           Marathon Petroleum  Energy            Petroleum Refining
# ...                         ...     ...                           ...
# 981                  WPX Energy  Energy  Mining, Crude-Oil Production
# 983    Adams Resources & Energy  Energy            Petroleum Refining
# 995                   EP Energy  Energy  Mining, Crude-Oil Production
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
#
#              Location  Revenue  Profits  Employees
# Rank
# 2          Irving, TX   246204    16150      75600
# ...

# %%
# how many in each sector
df['Sector'].value_counts()
# Out:
# Sector
# Financials                      139
# Energy                          122
# Technology                      102
# Retailing                        80
# Health Care                      75
# Business Services                51
# Industrials                      46
# Materials                        43
# Food, Beverages & Tobacco        43
# Wholesalers                      40
# Transportation                   36
# Chemicals                        30
# Household Products               28
# Engineering & Construction       26
# Media                            25
# Hotels, Resturants & Leisure     25
# Motor Vehicles & Parts           24
# Aerospace & Defense              20
# Telecommunications               15
# Food and Drug Stores             15
# Apparel                          15
# Name: count, dtype: int64

# %%
# separate each group into dataframes named by its sector name

sectors = df.groupby(["Sector"])
for k, (key, group) in enumerate(sectors):
    print(k, key, end= "\n")
# Out:
# 0 ('Aerospace & Defense',)
# 1 ('Apparel',)
# 2 ('Business Services',)
# 3 ('Chemicals',)
# 4 ('Energy',)
# 5 ('Engineering & Construction',)
# 6 ('Financials',)
# 7 ('Food and Drug Stores',)
# 8 ('Food, Beverages & Tobacco',)
# 9 ('Health Care',)
# 10 ('Hotels, Resturants & Leisure',)
# 11 ('Household Products',)
# 12 ('Industrials',)
# 13 ('Materials',)
# 14 ('Media',)
# 15 ('Motor Vehicles & Parts',)
# 16 ('Retailing',)
# 17 ('Technology',)
# 18 ('Telecommunications',)
# 19 ('Transportation',)
# 20 ('Wholesalers',)

# %%
df['Sector'].nunique()
# Out:
# 21

# %%
df.nlargest(5, "Revenue")
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
df_h = pd.DataFrame(columns= df.columns)
df_h
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
# display highest revenue for each sector
for _, (key, data) in enumerate(sectors):
    #print(_, data.nlargest(1, "Revenue")) 
    highest_rev = data.nlargest(1, "Revenue")
    #print(type(highest_rev))
    df_h = pd.concat([df_h, highest_rev])
    
df_h
# Out:
#                     Company                        Sector  \
# 24                   Boeing           Aerospace & Defense
# 91                     Nike                       Apparel
# 144           ManpowerGroup             Business Services
# 56             Dow Chemical                     Chemicals
# 2               Exxon Mobil                        Energy
# 155                   Fluor    Engineering & Construction
# 4        Berkshire Hathaway                    Financials
# 7                CVS Health          Food and Drug Stores
# 41   Archer Daniels Midland     Food, Beverages & Tobacco
# 5                  McKesson                   Health Care
# 109              McDonald’s  Hotels, Resturants & Leisure
# 34         Procter & Gamble            Household Products
# 11         General Electric                   Industrials
# 126                   Alcoa                     Materials
# 53                   Disney                         Media
# ...

# %%
df.sort_values(by= 'Revenue', ascending= False).head(21)
# Out:
#                        Company                  Sector  \
# Rank
# 1                      Walmart               Retailing
# 2                  Exxon Mobil                  Energy
# 3                        Apple              Technology
# 4           Berkshire Hathaway              Financials
# 5                     McKesson             Health Care
# 6           UnitedHealth Group             Health Care
# 7                   CVS Health    Food and Drug Stores
# 8               General Motors  Motor Vehicles & Parts
# 9                   Ford Motor  Motor Vehicles & Parts
# 10                        AT&T      Telecommunications
# 11            General Electric             Industrials
# 12           AmerisourceBergen             Health Care
# 13                     Verizon      Telecommunications
# 14                     Chevron                  Energy
# 15                      Costco               Retailing
# 16                  Fannie Mae              Financials
# ...
